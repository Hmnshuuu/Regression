# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r"C:\Users\himan\Music\2.1 UNZIP_ME_FOR_NOTEBOOKS_V4\08-Linear-Regression-Models/Advertising.csv"

# Read the CSV file using the absolute path
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
 fig,axes = plt.subplots(nrows = 1,ncols = 3,figsize = (16,6))
 axes[0].plot(df['TV'],df['sales'],'o')
 axes[0].set_ylabel("Sales")
 axes[0].set_title("TV Spend")

 axes[1].plot(df['radio'],df['sales'],'o')
 axes[1].set_ylabel("Radio Spend")
 axes[1].set_title("Sales")
    
 axes[2].plot(df['newspaper'],df['sales'],'o')
 axes[2].set_ylabel("Newspaper Spend")
 axes[2].set_title("Sales")

plt.tight_layout();

# %%
sns.pairplot(df)

# %%
 X = df.drop('sales',axis = 1)

# %%
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y = df['sales']

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
help(train_test_split)
# Out:
# Help on function train_test_split in module sklearn.model_selection._split:
#
# train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)
#     Split arrays or matrices into random train and test subsets.
#
#     Quick utility that wraps input validation and
#     ``next(ShuffleSplit().split(X, y))`` and application to input data
#     into a single call for splitting (and optionally subsampling) data in a
#     oneliner.
#
#     Read more in the :ref:`User Guide <cross_validation>`.
#
#     Parameters
#     ----------
#     *arrays : sequence of indexables with same length / shape[0]
#         Allowed inputs are lists, numpy arrays, scipy-sparse
#         matrices or pandas dataframes.
#
#     test_size : float or int, default=None
#         If float, should be between 0.0 and 1.0 and represent the proportion
#         of the dataset to include in the test split. If int, represents the
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

#test size is wht percentage of data going to test
#random state is used to random seed(isko hmesa same rkho 101) or ye array ko shuffle bi krta h phle

# %%
len(df)
# Out:
# 200

# %%
X_train 
#yha niche random state ne shuffle krdia or 140 rows mtlb 70% data train h
# Out:
#         TV  radio  newspaper
# 85   193.2   18.4       65.7
# 183  287.6   43.0       71.8
# 127   80.2    0.0        9.2
# 53   182.6   46.2       58.7
# 100  222.4    4.3       49.8
# ..     ...    ...        ...
# 63   102.7   29.6        8.4
# 70   199.1   30.6       38.7
# 81   239.8    4.1       36.9
# 11   214.7   24.0        4.0
# 95   163.3   31.6       52.9
#
# [140 rows x 3 columns]

# %%
y_train
# Out:
# 85     15.2
# 183    26.2
# 127     8.8
# 53     21.2
# 100    11.7
#        ...
# 63     14.0
# 70     18.3
# 81     12.3
# 11     17.4
# 95     16.9
# Name: sales, Length: 140, dtype: float64

# %%
X_test
# Out:
#         TV  radio  newspaper
# 37    74.7   49.4       45.7
# 109  255.4   26.9        5.5
# 31   112.9   17.4       38.6
# 89   109.8   47.8       51.4
# 66    31.5   24.6        2.2
# 119   19.4   16.0       22.3
# 54   262.7   28.8       15.9
# 74   213.4   24.6       13.1
# 145  140.3    1.9        9.0
# 142  220.5   33.2       37.9
# 148   38.0   40.3       11.9
# 112  175.7   15.4        2.4
# 174  222.4    3.4       13.1
# 55   198.9   49.4       60.0
# 141  193.7   35.4       75.6
# 149   44.7   25.8       20.6
# 25   262.9    3.5       19.5
# 34    95.7    1.4        7.4
# 170   50.0   11.6       18.4
# 39   228.0   37.7       32.0
# 172   19.6   20.1       17.0
# 153  171.3   39.7       37.7
# 175  276.9   48.9       41.8
# 61   261.3   42.7       54.7
# 65    69.0    9.3        0.9
# 50   199.8    3.1       34.6
# 42   293.6   27.7        1.8
# 129   59.6   12.0       43.1
# 179  165.6   10.0       17.6
# 2     17.2   45.9       69.3
# 12    23.8   35.1       65.9
# ...

# %%
len(X_test)
# Out:
# 60

# %%
#creating model
from sklearn.linear_model import LinearRegression

# %%
#help(LinearRegression)

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test) #ye yha isne predict krdia for all y values
# Out:
# array([15.74131332, 19.61062568, 11.44888935, 17.00819787,  9.17285676,
#         7.01248287, 20.28992463, 17.29953992,  9.77584467, 19.22194224,
#        12.40503154, 13.89234998, 13.72541098, 21.28794031, 18.42456638,
#         9.98198406, 15.55228966,  7.68913693,  7.55614992, 20.40311209,
#         7.79215204, 18.24214098, 24.68631904, 22.82199068,  7.97962085,
#        12.65207264, 21.46925937,  8.05228573, 12.42315981, 12.50719678,
#        10.77757812, 19.24460093, 10.070269  ,  6.70779999, 17.31492147,
#         7.76764327,  9.25393336,  8.27834697, 10.58105585, 10.63591128,
#        13.01002595,  9.77192057, 10.21469861,  8.04572042, 11.5671075 ,
#        10.08368001,  8.99806574, 16.25388914, 13.23942315, 20.81493419,
#        12.49727439, 13.96615898, 17.56285075, 11.14537013, 12.56261468,
#         5.50870279, 23.29465134, 12.62409688, 18.77399978, 15.18785675])

# %%
test_predictions =  model.predict(X_test)

# %%
#X_test.head()

# %%
#y_test

# %%
#test_predictions

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
df['sales'].mean()
# Out:
# 14.022500000000003

# %%
sns.histplot(data=df,x='sales',bins =20)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Count'>

# %%
mean_absolute_error(y_test,test_predictions)

#less than 10% aai h jo ki shi hi h
# Out:
# 1.2137457736144803

# %%
#RMSE
np.sqrt(mean_squared_error(y_test,test_predictions))
# Out:
# 1.5161519375993877

# %%
test_residuals = y_test - test_predictions

# %%
#test_residuals

# -ve mtlb over estimated
# +ve mtlb under estimated

# %%
sns.scatterplot(x=y_test,y=test_residuals)
plt.axhline(y=0,color = 'red',ls ='--')

#ye esa random aaya h boht jyada to linear regression not use bhdia yha

# %%
sns.displot(test_residuals,bins=25,kde=True)

# %%
import scipy as sp

# %%
fig,ax = plt.subplots(figsize = (6,8),dpi = 100)
_ = sp.stats.probplot(test_residuals,plot =ax)

#it check plot is normally distributed r not

# %%
 final_model = LinearRegression()

# %%
final_model.fit(X,y)   #it taked full data set
# Out:
# LinearRegression()

# %%
final_model.coef_

#arr[0] for tv,arr[1] for radio , arr[2] fror newspaper
#agr koi coeficient 0 k lgbhag rhega to uska mtlb uska boht kam impact h model pe
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
X.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y_hat = final_model.predict(X)

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(16,6))

axes[0].plot(df['TV'],df['sales'],'o')
axes[0].plot(df['TV'],y_hat,'o',color='red')
axes[0].set_ylabel("Sales")
axes[0].set_title("TV Spend")

axes[1].plot(df['radio'],df['sales'],'o')
axes[1].plot(df['radio'],y_hat,'o',color='red')
axes[1].set_title("Radio Spend")
axes[1].set_ylabel("Sales")

axes[2].plot(df['newspaper'],df['sales'],'o')
axes[2].plot(df['radio'],y_hat,'o',color='red')
axes[2].set_title("Newspaper Spend");
axes[2].set_ylabel("Sales")
plt.tight_layout();

#predicted - red , truepoints - blue

# %%
from joblib import dump,load

# %%
dump(final_model,'final_sales_model.joblib')
# Out:
# ['final_sales_model.joblib']

# %%
loaded_model = load('final_sales_model.joblib')

# %%
loaded_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
X.shape
# Out:
# (200, 3)

# %%
#149 TV , 22 radio , 12 newspaper
campaign = [[149,22,12]]

# %%
loaded_model.predict(campaign)
# Out:
# C:\Users\himan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13.893032])
